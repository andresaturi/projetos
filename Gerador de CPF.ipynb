# %%
from random import randint


def geradorcpf(*num):
    print("Quantos CPF'S deseja criar?")
    q = int(input())

    for n in range(0, q):      
      bloco1 = str(randint(100, 999))
      bloco2 = str(randint(100, 999))
      bloco3 = str(randint(100, 999))
      cpflist = list(f'{bloco1}{bloco2}{bloco3}')
      cpfint = [int(numero) for numero in cpflist]  
    
        # Digito 1
      soma = list()
      c = 10
      for numero in cpfint:
          soma.append(numero*c)
          c -= 1
      digito1 = 11 - (sum(soma) % 11)
      if digito1 > 9:
          digito1 = 0
      cpfint.append(digito1)

      # Digito 2
      soma = list()
      c = 11
      for numero in cpfint:
          soma.append(numero*c)
          c -= 1
      digito2 = 11 - (sum(soma) % 11)
      if digito2 > 9:
          digito2 = 0
      cpfint.append(digito2)
      gerado = f'{bloco1}.{bloco2}.{bloco3}-{digito1}{digito2}'
      print(gerado)
    
      
geradorcpf()
# Out:
# Quantos CPF'S deseja criar?
# 20
# 705.188.693-26
# 393.509.361-60
# 265.640.318-90
# 453.672.679-98
# 928.184.817-16
# 295.619.262-02
# 843.831.925-48
# 101.900.873-31
# 423.734.321-96
# 764.606.731-87
# 754.480.669-33
# 887.786.780-99
# 993.259.183-15
# 163.124.356-01
# 266.231.641-11
# 686.616.512-12
# 359.747.316-46
# 525.937.880-62
# 103.868.640-71
# 807.708.816-37
